# %% [markdown]
# ![image.png](attachment:image.png)

# %%
l = [2,5,3,767,-3,5,-45]

# %%
l
# Out:
# [2, 5, 3, 767, -3, 5, -45]

# %%
l[0]
# Out:
# 2

# %%
l[3]
# Out:
# 767

# %%
l[:]
# Out:
# [2, 5, 3, 767, -3, 5, -45]

# %%
l[:3]
# Out:
# [2, 5, 3]

# %%
l[4:]
# Out:
# [-3, 5, -45]

# %%
l[3:5]
# Out:
# [767, -3]

# %%
#從後面開始數(負的)也可以
l[-1]
# Out:
# -45

# %%
l[-5]
# Out:
# 3

# %%
l[-4:-1]  #注意寫的順序仍是要由前面來算,否則
# Out:
# [767, -3, 5]

# %%
l[-1:-4] #就會這樣
# Out:
# []

# %%
l[-3:]
# Out:
# [-3, 5, -45]

# %%
l[:-3]
# Out:
# [2, 5, 3, 767]
