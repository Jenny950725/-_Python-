# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
import pandas_datareader as web

# %% [markdown]
# dataframe = web.DataReader("股票名字","資訊來源",start="日期",end="日期")
#
# AAPL => 蘋果
#
# 資訊來源通常是yahoo

# %%
df = web.DataReader("AAPL","yahoo",start="2020-1-1",end="2022-5-17")

# %%
df.head()
# Out:
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2019-12-31  73.419998  72.379997  72.482498  73.412498  100805600.0  72.139954
# 2020-01-02  75.150002  73.797501  74.059998  75.087502  135480400.0  73.785912
# 2020-01-03  75.144997  74.125000  74.287498  74.357498  146322800.0  73.068565
# 2020-01-06  74.989998  73.187500  73.447502  74.949997  118387200.0  73.650795
# 2020-01-07  75.224998  74.370003  74.959999  74.597504  108872000.0  73.304428

# %%
P = df["Adj Close"]  #只看收盤價

# %%
P
# Out:
# Date
# 2019-12-31     72.139954
# 2020-01-02     73.785912
# 2020-01-03     73.068565
# 2020-01-06     73.650795
# 2020-01-07     73.304428
#                  ...
# 2022-05-11    146.500000
# 2022-05-12    142.559998
# 2022-05-13    147.110001
# 2022-05-16    145.539993
# 2022-05-17    149.240005
# Name: Adj Close, Length: 600, dtype: float64

# %%
P.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ## 計算報酬率

# %% [markdown]
# 跟前一期的差
#
# dataframe.diff()

# %%
P.diff()
# Out:
# Date
# 2019-12-31         NaN
# 2020-01-02    1.645958
# 2020-01-03   -0.717346
# 2020-01-06    0.582230
# 2020-01-07   -0.346367
#                 ...
# 2022-05-11   -8.009995
# 2022-05-12   -3.940002
# 2022-05-13    4.550003
# 2022-05-16   -1.570007
# 2022-05-17    3.700012
# Name: Adj Close, Length: 600, dtype: float64

# %% [markdown]
# 報酬率:這期和上期的差/上期

# %%
r= P.diff()/P

# %%
r.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# 報酬率上上下下
#
# 取100天的資料來看看

# %%
r[-100:].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ## 移動平均

# %%
P.rolling(window=20).mean().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
P.plot()
P.rolling(window=20).mean().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# 橘色(移動平均)較原圖平滑

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
P.plot()
P.rolling(window=20).mean().plot()
P.rolling(window=90).mean().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# window=90的線最平滑
