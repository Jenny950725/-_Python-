# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
A = np.random.randn(50)

# %%
A #50個數字 平均值0 標準差1
# Out:
# array([ 1.90097731, -1.53238305, -0.66797216, -0.34343194,  0.57336998,
#         0.34563127,  0.57104452, -0.09914676, -0.41805043, -0.1877563 ,
#         0.52943388,  0.47252529, -0.21179959, -0.46274126, -0.67236387,
#         1.23571603,  0.07513523,  1.24190019,  0.64613607, -0.36095623,
#         1.24580724,  1.25611393, -0.06667195,  1.61170573,  0.48427432,
#         1.75834494, -1.21967002,  0.61003294, -1.50637168, -0.96788931,
#        -0.42179432,  1.25724537,  0.414898  , -0.06880212, -0.29396852,
#         0.17194736, -1.48039848, -0.53371309,  0.19572659, -1.14876987,
#         0.63321747, -0.50617609, -0.12567947, -0.10978417, -1.9981385 ,
#        -0.59406632, -0.51282046, -1.29954048, -0.30850272, -0.6106683 ])

# %%
#把平均值變50 標準差變10
A = 10*A + 50

# %%
A
# Out:
# array([69.00977313, 34.67616952, 43.32027842, 46.5656806 , 55.73369985,
#        53.45631272, 55.71044521, 49.00853238, 45.81949571, 48.12243698,
#        55.2943388 , 54.72525293, 47.88200409, 45.37258739, 43.27636127,
#        62.35716034, 50.75135226, 62.41900194, 56.46136069, 46.39043767,
#        62.45807238, 62.56113928, 49.33328051, 66.11705726, 54.84274322,
#        67.58344941, 37.80329983, 56.10032944, 34.93628319, 40.32110688,
#        45.78205683, 62.57245374, 54.14897999, 49.31197882, 47.06031475,
#        51.71947362, 35.19601517, 44.66286911, 51.95726586, 38.51230128,
#        56.33217467, 44.93823907, 48.74320531, 48.90215826, 30.01861496,
#        44.05933677, 44.87179535, 37.00459523, 46.91497282, 43.89331697])

# %% [markdown]
# 看array的形狀: 是50維的向量

# %%
A.shape
# Out:
# (50,)

# %% [markdown]
#  array.shape = (新的形狀)

# %%
A.shape = (5,10)

# %%
A #五個list，裡頭各有10個小項
# Out:
# array([[69.00977313, 34.67616952, 43.32027842, 46.5656806 , 55.73369985,
#         53.45631272, 55.71044521, 49.00853238, 45.81949571, 48.12243698],
#        [55.2943388 , 54.72525293, 47.88200409, 45.37258739, 43.27636127,
#         62.35716034, 50.75135226, 62.41900194, 56.46136069, 46.39043767],
#        [62.45807238, 62.56113928, 49.33328051, 66.11705726, 54.84274322,
#         67.58344941, 37.80329983, 56.10032944, 34.93628319, 40.32110688],
#        [45.78205683, 62.57245374, 54.14897999, 49.31197882, 47.06031475,
#         51.71947362, 35.19601517, 44.66286911, 51.95726586, 38.51230128],
#        [56.33217467, 44.93823907, 48.74320531, 48.90215826, 30.01861496,
#         44.05933677, 44.87179535, 37.00459523, 46.91497282, 43.89331697]])

# %% [markdown]
# 如果數字給錯，讓他們相乘不等於10 則python不給過

# %%
A.shape = (5,40)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13612/436010420.py in <module>
#       1 #如果數字給錯，讓他們相乘不等於10 python不給過
# ----> 2 A.shape = (5,40)
#
# ValueError: cannot reshape array of size 50 into shape (5,40)

# %%
A.reshape(50,1)
# Out:
# array([[69.00977313],
#        [34.67616952],
#        [43.32027842],
#        [46.5656806 ],
#        [55.73369985],
#        [53.45631272],
#        [55.71044521],
#        [49.00853238],
#        [45.81949571],
#        [48.12243698],
#        [55.2943388 ],
#        [54.72525293],
#        [47.88200409],
#        [45.37258739],
#        [43.27636127],
#        [62.35716034],
#        [50.75135226],
#        [62.41900194],
#        [56.46136069],
#        [46.39043767],
#        [62.45807238],
#        [62.56113928],
#        [49.33328051],
#        [66.11705726],
#        [54.84274322],
#        [67.58344941],
#        [37.80329983],
#        [56.10032944],
#        [34.93628319],
#        [40.32110688],
#        [45.78205683],
#        [62.57245374],
#        [54.14897999],
#        [49.31197882],
#        [47.06031475],
#        [51.71947362],
#        [35.19601517],
#        [44.66286911],
#        [51.95726586],
#        [38.51230128],
#        [56.33217467],
# ...

# %% [markdown]
# reshape不會改變原本的array

# %%
A
# Out:
# array([[69.00977313, 34.67616952, 43.32027842, 46.5656806 , 55.73369985,
#         53.45631272, 55.71044521, 49.00853238, 45.81949571, 48.12243698],
#        [55.2943388 , 54.72525293, 47.88200409, 45.37258739, 43.27636127,
#         62.35716034, 50.75135226, 62.41900194, 56.46136069, 46.39043767],
#        [62.45807238, 62.56113928, 49.33328051, 66.11705726, 54.84274322,
#         67.58344941, 37.80329983, 56.10032944, 34.93628319, 40.32110688],
#        [45.78205683, 62.57245374, 54.14897999, 49.31197882, 47.06031475,
#         51.71947362, 35.19601517, 44.66286911, 51.95726586, 38.51230128],
#        [56.33217467, 44.93823907, 48.74320531, 48.90215826, 30.01861496,
#         44.05933677, 44.87179535, 37.00459523, 46.91497282, 43.89331697]])

# %%
A = A.reshape(50,1)

# %%
A #改過來了
# Out:
# array([[69.00977313],
#        [34.67616952],
#        [43.32027842],
#        [46.5656806 ],
#        [55.73369985],
#        [53.45631272],
#        [55.71044521],
#        [49.00853238],
#        [45.81949571],
#        [48.12243698],
#        [55.2943388 ],
#        [54.72525293],
#        [47.88200409],
#        [45.37258739],
#        [43.27636127],
#        [62.35716034],
#        [50.75135226],
#        [62.41900194],
#        [56.46136069],
#        [46.39043767],
#        [62.45807238],
#        [62.56113928],
#        [49.33328051],
#        [66.11705726],
#        [54.84274322],
#        [67.58344941],
#        [37.80329983],
#        [56.10032944],
#        [34.93628319],
#        [40.32110688],
#        [45.78205683],
#        [62.57245374],
#        [54.14897999],
#        [49.31197882],
#        [47.06031475],
#        [51.71947362],
#        [35.19601517],
#        [44.66286911],
#        [51.95726586],
#        [38.51230128],
#        [56.33217467],
# ...
