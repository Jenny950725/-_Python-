# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# (以後不要用的指令)
# 可以算數學、畫圖、產生變數

# %%
pi
# Out:
# 3.141592653589793

# %%
##畫圖
plot([2,5,3,-6,7,-1])

# %%
##產生亂數
randn(10)
# Out:
# array([ 2.37593498e-01, -4.09326313e-02,  2.50183225e+00, -7.87426114e-01,
#         4.36855213e-02,  1.40610389e+00, -3.37714778e-01, -1.50681221e-01,
#        -2.38221551e-03,  1.09201237e+00])

# %%
##把亂數描點出來
plot(randn(50))

# %%
##用plot畫圖
##plot([x座標,x座標,x座標],[y座標,y座標,y座標])
plot([2,5,7,-3,3],[4,-2,6,5,-9])

# %%
##畫正方形
plot([2,4,4,2,2],[1,1,3,3,1])
