# %%
# %matplotlib inline 
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# %matplotlib inline
#
# 如果要畫圖，直接呈現在網頁上，不要跳其他網頁
#
# 與pylab的差別:pylab讀了很多套件，而且有點混亂
#
#
# np和plt都是常見的縮寫

# %%
np.pi
# Out:
# 3.141592653589793

# %%
plt.plot([1,64,-5,3,7,39,3,18,-93])

# %% [markdown]
# 要用的時候 套件名.函數名

# %%
#畫出亂數
plt.plot(np.random.randn(400))

# %% [markdown]
# 如果打指令打到忘記，就按一下tab鍵，會自動補好或讓你選

# %%
# %matplotlib
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Using matplotlib backend: Qt5Agg
