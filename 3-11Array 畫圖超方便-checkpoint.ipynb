# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
y = np.random.rand(50) #取0~1的亂數 50個

# %%
y
# Out:
# array([0.54642624, 0.80944589, 0.19354201, 0.59563093, 0.83812201,
#        0.53471374, 0.49771649, 0.85403242, 0.64040622, 0.03244147,
#        0.88314494, 0.7452632 , 0.9904547 , 0.47433285, 0.46020028,
#        0.41114382, 0.19410249, 0.26639638, 0.32254761, 0.30909928,
#        0.37657091, 0.81714486, 0.71003269, 0.50929339, 0.46814073,
#        0.98847631, 0.35953675, 0.66443959, 0.55988085, 0.31551239,
#        0.77466413, 0.56157741, 0.93708044, 0.72738295, 0.26510835,
#        0.53661778, 0.04029595, 0.1524691 , 0.15618371, 0.55364783,
#        0.22291766, 0.8250096 , 0.62540662, 0.89079574, 0.04385844,
#        0.15973909, 0.98030356, 0.96414728, 0.19869304, 0.09949906])

# %%
plt.plot(y)

# %%
x = np.linspace(0,10,100) #描點法:建立一連串的點，x = np.linspace(起點,終點,多少個點)

# %%
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
# ...

# %%
plt.plot(x,np.sin(x))

# %%
plt.plot(x,np.sin(x)+x)

# %%
plt.plot(x,np.sin(x)+x)
plt.plot(x,np.cos(x)+x) #可同時畫兩個圖
